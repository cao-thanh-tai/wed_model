# %% [markdown]
# # Model Information
#
# Điền thông tin tổng quan về model ở đây để dùng cho bước tích hợp AI Hub.
#
# - Tên model:
# - Bài toán:
# - Framework:
# - Input:
# - Output:
# - Metric:

# %%
# Dán phần import và định nghĩa kiến trúc model vào đây.
# Ví dụ: class MyModel(nn.Module): ...

# %%
# Dán phần preprocessing và cách tạo input mẫu vào đây.
# Cho biết model nhận input có shape, kiểu dữ liệu và preprocessing nào.

# %%
# Dán phần load best model và inference vào đây.
# Ví dụ: model.load_state_dict(torch.load(...))

# %% [markdown]
# ## Integration Notes
#
# Ghi thêm các thông tin cần thiết: label mapping, threshold, kích thước ảnh, normalization, output format và cách postprocess.
